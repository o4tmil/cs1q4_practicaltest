# %% [markdown]
# <a href="https://colab.research.google.com/github/o4tmil/cs1q4_practicaltest/blob/main/cs1q4_practicaltest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = (input("ENTER NAME:"))
score_number = int(input("HOW MANY SCORES WILL YOU INPUT?:"))

for score_number in range(score_number):
  input_score = int(input("ENTER SCORE:"))
  scores = []

def score(score_list, score_number):
    return sum(score_list) / score_number

  print(score(scores, score_number))
# Out:
#   File "<tokenize>", line 11
#     print(score(scores, score_number))
#     ^
# IndentationError: unindent does not match any outer indentation level
